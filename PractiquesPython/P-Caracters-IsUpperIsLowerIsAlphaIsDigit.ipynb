# %% [markdown]
# # Problemes de funcions de cadenes, islower, isupper, isalpha, lower i upper

# %% [markdown]
# **1**. Comprova si un caràcter és lletra minúscula o majúscula

# %%
caracter = input("Introdueix un caràcter: ")
comprovar_lletra(caracter)
# Out:
# Introdueix un caràcter: R
# És una lletra majúscula.

# %% [markdown]
# **2**. Comprova si una cadena (string) conté només lletres. Prova d'introduir diversos textos fins que et retorni que la cadena només té lletres.

# %%
text = input("Introdueix un text: ")
comprovar_nomes_lletres(text)
# Out:
# Introdueix un text: El meu avi va anar a Cuba
# La cadena conté caràcters no alfabètics.

# %% [markdown]
# **3**. Converteix una cadena a majúscules

# %%
text = input("Introdueix un text: ")
convertir_a_majuscules(text)
# Out:
# Introdueix un text: El meu avi va anar a Cuba
# La cadena en majúscules és: EL MEU AVI VA ANAR A CUBA

# %% [markdown]
# **4**. Converteix una cadena a minúscules

# %%
text = input("Introdueix un text: ")
convertir_a_minuscules(text)
# Out:
# Introdueix un text: El meu avi va anar a Cuba
# La cadena en minúscules és: el meu avi va anar a cuba

# %% [markdown]
# **5**. Comprova si una cadena conté lletres minúscules

# %%
text = input("Introdueix un text: ")
comprovar_minuscules(text)
# Out:
# Introdueix un text: El meu avi va anar a Cuba
# La cadena conté lletres minúscules.

# %% [markdown]
# **6**. Comprova si una cadena conté lletres majúscules

# %%
text = input("Introdueix un text: ")
comprovar_majuscules(text)
# Out:
# Introdueix un text: El meu avi va anar a Cuba
# La cadena conté lletres majúscules.

# %% [markdown]
# **7**. Comprova si una cadena està en majúscules

# %%
text = input("Introdueix un text: ")
comprovar_majuscules_tot(text)
# Out:
# Introdueix un text: El meu avi va anar a Cuba
# La cadena no està en majúscules.

# %% [markdown]
# **8**. Comprova si una cadena està en minúscules

# %%
text = input("Introdueix un text: ")
comprovar_minuscules_tot(text)
# Out:
# Introdueix un text: El meu avi va anar a Cuba
# La cadena no està en minúscules.

# %% [markdown]
# **9**. Comprova si una cadena comença amb majúscula

# %%
text = input("Introdueix un text: ")
comprovar_inici_majuscules(text)
# Out:
# Introdueix un text: El meu avi va anar a Cuba
# La cadena comença amb majúscula.

# %% [markdown]
# **10**. Comprova si una cadena comença amb minúscula

# %%
text = input("Introdueix un text: ")
comprovar_inici_minuscules(text)
# Out:
# Introdueix un text: El meu avi va anar a Cuba
# La cadena no comença amb minúscula.

# %% [markdown]
# **11**. Comprova si una cadena conté només lletres i espais

# %%
text = input("Introdueix un text: ")
comprovar_lletres_i_espais(text)
# Out:
# Introdueix un text: El meu avi va anar a Cuba
# El string conté només lletres i espais.

# %% [markdown]
# **12**. Comprovar si una cadena conté només lletres i dígits.

# %%
text = input("Introdueix un text: ")
comprovar_lletres_i_digits(text)
# Out:
# Introdueix un text: El meu avi té 70 anys
# La cadena conté caràcters no alfabètics o dígits.

# %% [markdown]
# **13**. Inventa't variacions dels problemes anteriors i escriu-ne l'enunciat, la solució i algunes proves de validació.

# %% [markdown]
# Aquesta llista de problemes i solucions ha estat preparada amb l'ajut de ChatGPT 3.5, versió 24 de maig de 2023, i revisada i adaptada per Mireia Ribera.
